# %%
import numpy as np
import pandas as pd

# %%
f_df1 = pd.read_csv('news_dfp.csv',index_col=0)
f_df1.shape
# Out:
# (1797, 2)

# %%
f_df2 = pd.read_csv('news_dfe.csv',index_col=0)
f_df2.shape
# Out:
# (1797, 2)

# %%
f_df3 = pd.read_csv('news_dfc.csv',index_col=0)
f_df3.shape
# Out:
# (2245, 2)

# %%
f_df4 = pd.read_csv('news_dfs.csv',index_col=0)
f_df4.shape
# Out:
# (1795, 2)

# %%
news2_df = pd.concat([f_df1,f_df2,f_df3,f_df4],axis=0)
news2_df.head()
# Out:
#                                            news_text  category
# 0       (서울=연합뉴스) 26일 서울 용산구 합동참모본부에서 대통령 집무실 이전 ...       264
# 1      (서울=연합뉴스) 국회 국방위원회 민홍철 위원장과 더불어민주당 위원들이 26...       264
# 2  “경기지사 당선 시 직접 협상 나설 것”전날 협상장 찾아 “버스 멈추면 일상 멈춰”...       264
# 3  [서울경제] 이동기 코엑스 사장(오른쪽)과 류명현 한국도로협회 상임부회장이 26일 ...       264
# 4      (서울=연합뉴스) 국회 국방위원회 민홍철 위원장과 더불어민주당 위원들이 26...       264

# %%
news2_df.to_csv('news2_df.csv',mode='w')

# %%
new3= pd.read_csv('news2_df.csv',index_col=0)
new3
# Out:
#                                               news_text  category
# 0          (서울=연합뉴스) 26일 서울 용산구 합동참모본부에서 대통령 집무실 이전 ...       264
# 1         (서울=연합뉴스) 국회 국방위원회 민홍철 위원장과 더불어민주당 위원들이 26...       264
# 2     “경기지사 당선 시 직접 협상 나설 것”전날 협상장 찾아 “버스 멈추면 일상 멈춰”...       264
# 3     [서울경제] 이동기 코엑스 사장(오른쪽)과 류명현 한국도로협회 상임부회장이 26일 ...       264
# 4         (서울=연합뉴스) 국회 국방위원회 민홍철 위원장과 더불어민주당 위원들이 26...       264
# ...                                                 ...       ...
# 1790  박스에 ‘내부, 개발 전용’ 적혀깜박 잊었나 일부러 두고 갔나아이폰4·5처럼 마케팅...       230
# 1791  코로나19로 법인택시 기사 20% 감소플랫폼 업계, '수락률 제고' 노력에도공급 부...       230
# 1792  삼성전자의 한정판 스마트폰 ‘갤럭시Z 플립3 포켓몬 에디션<사진>’이 출시 13시간...       230
# 1793  유튜브 ‘올블랑TV’ 캡처여주엽 ‘올블랑’ 대표사람들은 ‘운동할 시간이 없다’는 이...       230
# 1794  국내 정보통신기술(ICT) 업계가 윤석열 대통령 당선인에게 ‘과학기술수석비서관’ 설...       230
#
# [7634 rows x 2 columns]

# %%
print(new3.isnull().sum(),'\n')
print(new3.nunique())
# Out:
# news_text    9
# category     0
# dtype: int64
#
# news_text    3580
# category       19
# dtype: int64

# %%
new3.dropna(inplace=True)
new3.drop_duplicates(subset=['news_text'],inplace=True)

# %%
new3.reset_index(drop=True,inplace=True)
new5_df = new3
new5_df
# Out:
#                                               news_text  category
# 0          (서울=연합뉴스) 26일 서울 용산구 합동참모본부에서 대통령 집무실 이전 ...       264
# 1         (서울=연합뉴스) 국회 국방위원회 민홍철 위원장과 더불어민주당 위원들이 26...       264
# 2     “경기지사 당선 시 직접 협상 나설 것”전날 협상장 찾아 “버스 멈추면 일상 멈춰”...       264
# 3     [서울경제] 이동기 코엑스 사장(오른쪽)과 류명현 한국도로협회 상임부회장이 26일 ...       264
# 4         (서울=연합뉴스) 국회 국방위원회 민홍철 위원장과 더불어민주당 위원들이 26...       264
# ...                                                 ...       ...
# 3575    촬영 버튼을 누르면 전·후면 카메라가 동시에 촬영한다. 사진도 동시에 업로드된다...       230
# 3576  박스에 ‘내부, 개발 전용’ 적혀깜박 잊었나 일부러 두고 갔나아이폰4·5처럼 마케팅...       230
# 3577  코로나19로 법인택시 기사 20% 감소플랫폼 업계, '수락률 제고' 노력에도공급 부...       230
# 3578  삼성전자의 한정판 스마트폰 ‘갤럭시Z 플립3 포켓몬 에디션<사진>’이 출시 13시간...       230
# 3579  국내 정보통신기술(ICT) 업계가 윤석열 대통령 당선인에게 ‘과학기술수석비서관’ 설...       230
#
# [3580 rows x 2 columns]

# %%
new5_df['news_text'].replace(" ", np.nan, inplace=True)

# %%
new5_df.isna().sum()
# Out:
# news_text    0
# category     0
# dtype: int64

# %%
new5_df
# Out:
#                                               news_text  category
# 0          (서울=연합뉴스) 26일 서울 용산구 합동참모본부에서 대통령 집무실 이전 ...       264
# 1         (서울=연합뉴스) 국회 국방위원회 민홍철 위원장과 더불어민주당 위원들이 26...       264
# 2     “경기지사 당선 시 직접 협상 나설 것”전날 협상장 찾아 “버스 멈추면 일상 멈춰”...       264
# 3     [서울경제] 이동기 코엑스 사장(오른쪽)과 류명현 한국도로협회 상임부회장이 26일 ...       264
# 4         (서울=연합뉴스) 국회 국방위원회 민홍철 위원장과 더불어민주당 위원들이 26...       264
# ...                                                 ...       ...
# 3575    촬영 버튼을 누르면 전·후면 카메라가 동시에 촬영한다. 사진도 동시에 업로드된다...       230
# 3576  박스에 ‘내부, 개발 전용’ 적혀깜박 잊었나 일부러 두고 갔나아이폰4·5처럼 마케팅...       230
# 3577  코로나19로 법인택시 기사 20% 감소플랫폼 업계, '수락률 제고' 노력에도공급 부...       230
# 3578  삼성전자의 한정판 스마트폰 ‘갤럭시Z 플립3 포켓몬 에디션<사진>’이 출시 13시간...       230
# 3579  국내 정보통신기술(ICT) 업계가 윤석열 대통령 당선인에게 ‘과학기술수석비서관’ 설...       230
#
# [3580 rows x 2 columns]

# %%
new2= pd.read_csv('news2_df.csv',index_col=0)
new2
# Out:
#                                               news_text  category
# 0          (서울=연합뉴스) 26일 서울 용산구 합동참모본부에서 대통령 집무실 이전 ...       264
# 1         (서울=연합뉴스) 국회 국방위원회 민홍철 위원장과 더불어민주당 위원들이 26...       264
# 2     “경기지사 당선 시 직접 협상 나설 것”전날 협상장 찾아 “버스 멈추면 일상 멈춰”...       264
# 3     [서울경제] 이동기 코엑스 사장(오른쪽)과 류명현 한국도로협회 상임부회장이 26일 ...       264
# 4         (서울=연합뉴스) 국회 국방위원회 민홍철 위원장과 더불어민주당 위원들이 26...       264
# ...                                                 ...       ...
# 1790  박스에 ‘내부, 개발 전용’ 적혀깜박 잊었나 일부러 두고 갔나아이폰4·5처럼 마케팅...       230
# 1791  코로나19로 법인택시 기사 20% 감소플랫폼 업계, '수락률 제고' 노력에도공급 부...       230
# 1792  삼성전자의 한정판 스마트폰 ‘갤럭시Z 플립3 포켓몬 에디션<사진>’이 출시 13시간...       230
# 1793  유튜브 ‘올블랑TV’ 캡처여주엽 ‘올블랑’ 대표사람들은 ‘운동할 시간이 없다’는 이...       230
# 1794  국내 정보통신기술(ICT) 업계가 윤석열 대통령 당선인에게 ‘과학기술수석비서관’ 설...       230
#
# [7634 rows x 2 columns]

# %%
new2['news_text'].replace(" ", np.nan, inplace=True)

# %%
new2.dropna(inplace=True)

# %%
new2
# Out:
#                                               news_text  category
# 0          (서울=연합뉴스) 26일 서울 용산구 합동참모본부에서 대통령 집무실 이전 ...       264
# 1         (서울=연합뉴스) 국회 국방위원회 민홍철 위원장과 더불어민주당 위원들이 26...       264
# 2     “경기지사 당선 시 직접 협상 나설 것”전날 협상장 찾아 “버스 멈추면 일상 멈춰”...       264
# 3     [서울경제] 이동기 코엑스 사장(오른쪽)과 류명현 한국도로협회 상임부회장이 26일 ...       264
# 4         (서울=연합뉴스) 국회 국방위원회 민홍철 위원장과 더불어민주당 위원들이 26...       264
# ...                                                 ...       ...
# 1790  박스에 ‘내부, 개발 전용’ 적혀깜박 잊었나 일부러 두고 갔나아이폰4·5처럼 마케팅...       230
# 1791  코로나19로 법인택시 기사 20% 감소플랫폼 업계, '수락률 제고' 노력에도공급 부...       230
# 1792  삼성전자의 한정판 스마트폰 ‘갤럭시Z 플립3 포켓몬 에디션<사진>’이 출시 13시간...       230
# 1793  유튜브 ‘올블랑TV’ 캡처여주엽 ‘올블랑’ 대표사람들은 ‘운동할 시간이 없다’는 이...       230
# 1794  국내 정보통신기술(ICT) 업계가 윤석열 대통령 당선인에게 ‘과학기술수석비서관’ 설...       230
#
# [7625 rows x 2 columns]

# %%
new2.drop_duplicates(subset=['news_text'],inplace=True)

# %%
new2
# Out:
#                                               news_text  category
# 0          (서울=연합뉴스) 26일 서울 용산구 합동참모본부에서 대통령 집무실 이전 ...       264
# 1         (서울=연합뉴스) 국회 국방위원회 민홍철 위원장과 더불어민주당 위원들이 26...       264
# 2     “경기지사 당선 시 직접 협상 나설 것”전날 협상장 찾아 “버스 멈추면 일상 멈춰”...       264
# 3     [서울경제] 이동기 코엑스 사장(오른쪽)과 류명현 한국도로협회 상임부회장이 26일 ...       264
# 4         (서울=연합뉴스) 국회 국방위원회 민홍철 위원장과 더불어민주당 위원들이 26...       264
# ...                                                 ...       ...
# 1765    촬영 버튼을 누르면 전·후면 카메라가 동시에 촬영한다. 사진도 동시에 업로드된다...       230
# 1766  박스에 ‘내부, 개발 전용’ 적혀깜박 잊었나 일부러 두고 갔나아이폰4·5처럼 마케팅...       230
# 1767  코로나19로 법인택시 기사 20% 감소플랫폼 업계, '수락률 제고' 노력에도공급 부...       230
# 1768  삼성전자의 한정판 스마트폰 ‘갤럭시Z 플립3 포켓몬 에디션<사진>’이 출시 13시간...       230
# 1770  국내 정보통신기술(ICT) 업계가 윤석열 대통령 당선인에게 ‘과학기술수석비서관’ 설...       230
#
# [3580 rows x 2 columns]

# %%
new2.to_csv('news22_df.csv',mode='w')

# %%
new22= pd.read_csv('news22_df.csv',index_col=0)
new22
# Out:
#                                               news_text  category
# 0          (서울=연합뉴스) 26일 서울 용산구 합동참모본부에서 대통령 집무실 이전 ...       264
# 1         (서울=연합뉴스) 국회 국방위원회 민홍철 위원장과 더불어민주당 위원들이 26...       264
# 2     “경기지사 당선 시 직접 협상 나설 것”전날 협상장 찾아 “버스 멈추면 일상 멈춰”...       264
# 3     [서울경제] 이동기 코엑스 사장(오른쪽)과 류명현 한국도로협회 상임부회장이 26일 ...       264
# 4         (서울=연합뉴스) 국회 국방위원회 민홍철 위원장과 더불어민주당 위원들이 26...       264
# ...                                                 ...       ...
# 1765    촬영 버튼을 누르면 전·후면 카메라가 동시에 촬영한다. 사진도 동시에 업로드된다...       230
# 1766  박스에 ‘내부, 개발 전용’ 적혀깜박 잊었나 일부러 두고 갔나아이폰4·5처럼 마케팅...       230
# 1767  코로나19로 법인택시 기사 20% 감소플랫폼 업계, '수락률 제고' 노력에도공급 부...       230
# 1768  삼성전자의 한정판 스마트폰 ‘갤럭시Z 플립3 포켓몬 에디션<사진>’이 출시 13시간...       230
# 1770  국내 정보통신기술(ICT) 업계가 윤석열 대통령 당선인에게 ‘과학기술수석비서관’ 설...       230
#
# [3580 rows x 2 columns]

# %%
set(new2)

# %%
import re
new2 = re.compile('[^a-zA-Z가-힣+]+', new2['news_text'])
new2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [19], in <cell line: 2>()
#       1 import re
# ----> 2 new2 = re.compile('[^a-zA-Z가-힣+]+', new2['news_text'])
#       3 new2
#
# File ~\anaconda3\envs\cakd5\lib\re.py:252, in compile(pattern, flags)
#     250 def compile(pattern, flags=0):
#     251     "Compile a regular expression pattern, returning a Pattern object."
# --> 252     return _compile(pattern, flags)
#
# File ~\anaconda3\envs\cakd5\lib\re.py:294, in _compile(pattern, flags)
#     292     flags = flags.value
#     293 try:
# --> 294     return _cache[type(pattern), pattern, flags]
#     295 except KeyError:
#     296     pass
#
# TypeError: unhashable type: 'Series'

# %%
def cleanText(data):
    text = re.sub('[^가-힣\s]+', '', data)
    return text
for i in range(len(new22)):
    new22['news_text'] = new22['news_text'].apply(cleanText)
new22
# Out:
#                                               news_text  category
# 0          서울연합뉴스 일 서울 용산구 합동참모본부에서 대통령 집무실 이전 관련 공사...       264
# 1         서울연합뉴스 국회 국방위원회 민홍철 위원장과 더불어민주당 위원들이 일 오후 ...       264
# 2     경기지사 당선 시 직접 협상 나설 것전날 협상장 찾아 버스 멈추면 일상 멈춰경기 버...       264
# 3     서울경제 이동기 코엑스 사장오른쪽과 류명현 한국도로협회 상임부회장이 일 서울 삼성동...       264
# 4         서울연합뉴스 국회 국방위원회 민홍철 위원장과 더불어민주당 위원들이 일 오후 ...       264
# ...                                                 ...       ...
# 1765    촬영 버튼을 누르면 전후면 카메라가 동시에 촬영한다 사진도 동시에 업로드된다 사...       230
# 1766  박스에 내부 개발 전용 적혀깜박 잊었나 일부러 두고 갔나아이폰처럼 마케팅 가능성미국...       230
# 1767  코로나로 법인택시 기사  감소플랫폼 업계 수락률 제고 노력에도공급 부족에 택시대란 ...       230
# 1768  삼성전자의 한정판 스마트폰 갤럭시 플립 포켓몬 에디션사진이 출시 시간여 만에 매진됐...       230
# 1770  국내 정보통신기술 업계가 윤석열 대통령 당선인에게 과학기술수석비서관 설치를 호소했다...       230
#
# [3580 rows x 2 columns]

# %%
new22.to_csv('news221_df.csv',mode='w')
